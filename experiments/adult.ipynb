# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/dev/Deep-Arguing

# %% [markdown]
# ## Deep Arguing Model

# %%
! python src/deeparguing/cli/run.py --config "tuning/adult/model_adult.yaml" "tuning/adult/hyperparameters_adult.yaml" "tuning/adult/data_adult.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 17:46:26,039 - INFO - ====================================================================================================
# 2026-05-06 17:46:26,039 - INFO - Running With Torch Seed: 0
# Epoch 5, Loss: 0.399743, Val Loss: 0.360652, Val Acc: 0.852142, Val F1: 0.803994
# 2026-05-06 17:46:44,272 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 17:46:44,272 - INFO - Accuracy: 0.8521; Precision: 0.796; Recall: 0.8136; F1: 0.804
# 2026-05-06 17:46:44,272 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-06 17:46:44,274 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1    4389     553
# Actual 0     410    1161
# 2026-05-06 17:46:44,609 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-06 17:46:44,609 - INFO - Accuracy: 0.8477; Precision: 0.7874; Recall: 0.803; F1: 0.7946
# ...

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/adult/baseline_nn_adult.yaml" "tuning/adult/data_adult.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 16:33:01,479 - INFO - ====================================================================================================
# 2026-05-04 16:33:01,479 - INFO - Running With Torch Seed: 0
# Epoch 5, Loss: 0.395442, Val Loss: 0.353243, Val Acc: 0.853984, Val F1: 0.805887
# 2026-05-04 16:33:02,937 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 16:33:02,938 - INFO - Accuracy: 0.854; Precision: 0.7985; Recall: 0.8146; F1: 0.8059
# 2026-05-04 16:33:02,938 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 16:33:02,939 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1    4402     540
# Actual 0     411    1160
# 2026-05-04 16:33:02,954 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-04 16:33:02,954 - INFO - Accuracy: 0.8455; Precision: 0.7844; Recall: 0.803; F1: 0.7928
# ...

# %% [markdown]
# ## DT Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/adult/baseline_dt_adult.yaml" "tuning/adult/data_adult.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 16:32:51,166 - INFO - ====================================================================================================
# 2026-05-04 16:32:51,166 - INFO - Running With Torch Seed: 0
# 2026-05-04 16:32:51,827 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 16:32:51,828 - INFO - Accuracy: 0.86; Precision: 0.8246; Recall: 0.7718; F1: 0.7927
# 2026-05-04 16:32:51,828 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 16:32:51,830 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1    4656     286
# Actual 0     626     945
# 2026-05-04 16:32:51,921 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-04 16:32:51,921 - INFO - Accuracy: 0.8553; Precision: 0.8153; Recall: 0.7592; F1: 0.7809
# ...

# %% [markdown]
# ## K-NN Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/adult/baseline_knn_adult.yaml" "tuning/adult/data_adult.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 18:58:40,181 - INFO - ====================================================================================================
# 2026-05-05 18:58:40,181 - INFO - Running With Torch Seed: 0
# 2026-05-05 18:58:40,955 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-05 18:58:40,955 - INFO - Accuracy: 0.8294; Precision: 0.768; Recall: 0.7569; F1: 0.7621
# 2026-05-05 18:58:40,955 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-05 18:58:40,958 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1    4433     509
# Actual 0     602     969
# 2026-05-05 18:58:41,335 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-05 18:58:41,335 - INFO - Accuracy: 0.8242; Precision: 0.7573; Recall: 0.742; F1: 0.749
# ...

# %% [markdown]
# ## Gradual AA-CBR (NeSy Paper)

# %%
! python src/deeparguing/cli/run.py --config "tuning/adult/nalcbr_adult.yaml" "tuning/adult/data_adult.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 17:48:01,388 - INFO - ====================================================================================================
# 2026-05-06 17:48:01,388 - INFO - Running With Torch Seed: 0
#   0%|                                                     | 0/6 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 372, in <module>
#     average_f1 = run(args.project)()
#                  ^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 173, in objective
#     max_val_acc, max_val_f1 = trainer.train(
#                               ^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/train/simple_trainer.py", line 111, in train
#     loss = self._train_step(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/train/simple_trainer.py", line 53, in _train_step
#     model.fit(X_casebase, y_casebase, X_default, y_default)
# ...
