# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/Documents/dev/gradual-aacbr

# %% [markdown]
# ## Deep Arguing Model

# %%
! python src/deeparguing/cli/run.py --config "tuning/cifar10/resnet/model_cifar10_image.yaml" "tuning/cifar10/resnet/hyperparameters_cifar10_image.yaml" "tuning/cifar10/resnet/data_cifar10_image.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 17:45:06,829 - INFO - ====================================================================================================
# 2026-05-05 17:45:06,829 - INFO - Running With Torch Seed: 0
# /home/adam/Documents/dev/gradual-aacbr/gradual-aacbr/lib/python3.14/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Epoch 4, Loss: 1.351974, Val Loss: 1.583792, Val Acc: 0.8357, Val F1: 0.836643:
# 2026-05-05 17:46:38,532 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-05 17:46:38,532 - INFO - Accuracy: 0.8357; Precision: 0.8413; Recall: 0.8361; F1: 0.8366
# 2026-05-05 17:46:38,532 - INFO - -------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/cifar10/resnet/baseline_resnet_cifar10_image.yaml" "tuning/cifar10/resnet/data_cifar10_image.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 19:19:54,183 - INFO - ====================================================================================================
# 2026-05-05 19:19:54,183 - INFO - Running With Torch Seed: 0
# /home/adam/Documents/dev/gradual-aacbr/gradual-aacbr/lib/python3.14/site-packages/torchvision/datasets/cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")
# Epoch 199, Loss: 0.061746, Val Loss: 1.361578, Val Acc: 0.831, Val F1: 0.831614:
# 2026-05-05 19:47:19,325 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-05 19:47:19,325 - INFO - Accuracy: 0.831; Precision: 0.8354; Recall: 0.8312; F1: 0.8316
# 2026-05-05 19:47:19,325 - INFO - -------------------------------------------------------------------------------------------
# ...
