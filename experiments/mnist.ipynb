# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/Documents/dev/gradual-aacbr

# %% [markdown]
# ## Deep Arguing Model

# %% [markdown]
# Note there is a bug with the weights of the CNN not initialsing correctly when running each seed sequentially in one go, so instead each was run separately and the results averaged.

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/data_mnist.yaml" "tuning/mnist/hyperparameters_mnist.yaml" "tuning/mnist/model_mnist.yaml" --seed "0" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:34:18,898 - INFO - ====================================================================================================
# 2026-05-06 15:34:18,898 - INFO - Running With Torch Seed: 0
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.34942, Val Loss: 0.394991, Val Acc: 0.969167, Val F1: 0.968765:
# 2026-05-06 15:36:17,365 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:36:17,365 - INFO - Accuracy: 0.9692; Precision: 0.9693; Recall: 0.9687; F1: 0.9688
# 2026-05-06 15:36:17,365 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/data_mnist.yaml" "tuning/mnist/hyperparameters_mnist.yaml" "tuning/mnist/model_mnist.yaml" --seed "1" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:36:25,240 - INFO - ====================================================================================================
# 2026-05-06 15:36:25,241 - INFO - Running With Torch Seed: 1
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.420159, Val Loss: 0.48042, Val Acc: 0.947667, Val F1: 0.947297:
# 2026-05-06 15:38:31,161 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:38:31,161 - INFO - Accuracy: 0.9477; Precision: 0.9478; Recall: 0.9481; F1: 0.9473
# 2026-05-06 15:38:31,161 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/data_mnist.yaml" "tuning/mnist/hyperparameters_mnist.yaml" "tuning/mnist/model_mnist.yaml" --seed "2" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:53:42,442 - INFO - ====================================================================================================
# 2026-05-06 15:53:42,443 - INFO - Running With Torch Seed: 2
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.494758, Val Loss: 0.469521, Val Acc: 0.951, Val F1: 0.950573: 1
# 2026-05-06 15:55:45,194 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:55:45,194 - INFO - Accuracy: 0.951; Precision: 0.9509; Recall: 0.9509; F1: 0.9506
# 2026-05-06 15:55:45,194 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/data_mnist.yaml" "tuning/mnist/hyperparameters_mnist.yaml" "tuning/mnist/model_mnist.yaml" --seed "3" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:40:57,053 - INFO - ====================================================================================================
# 2026-05-06 15:40:57,053 - INFO - Running With Torch Seed: 3
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.432067, Val Loss: 0.456199, Val Acc: 0.953833, Val F1: 0.953214
# 2026-05-06 15:42:55,164 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:42:55,164 - INFO - Accuracy: 0.9538; Precision: 0.9559; Recall: 0.9528; F1: 0.9532
# 2026-05-06 15:42:55,164 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/data_mnist.yaml" "tuning/mnist/hyperparameters_mnist.yaml" "tuning/mnist/model_mnist.yaml" --seed "4" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:43:03,343 - INFO - ====================================================================================================
# 2026-05-06 15:43:03,343 - INFO - Running With Torch Seed: 4
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.362019, Val Loss: 0.375288, Val Acc: 0.976417, Val F1: 0.976328
# 2026-05-06 15:45:02,489 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:45:02,489 - INFO - Accuracy: 0.9764; Precision: 0.9764; Recall: 0.9764; F1: 0.9763
# 2026-05-06 15:45:02,489 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
import numpy as np 

x = np.array([0.9730725353033517, 0.9529378311159808, 0.9515885320720049, 0.9555953454782731, 0.982041196245293])

print(x.mean())
print(x.std())
# Out:
# 0.9630470880429807
# 0.012249977852864725

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/baseline_cnn_mnist.yaml" "tuning/mnist/data_mnist.yaml" --seed "0" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:45:10,711 - INFO - ====================================================================================================
# 2026-05-06 15:45:10,711 - INFO - Running With Torch Seed: 0
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.052471, Val Loss: 0.08246, Val Acc: 0.974833, Val F1: 0.974657:
# 2026-05-06 15:45:19,782 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:45:19,782 - INFO - Accuracy: 0.9748; Precision: 0.9753; Recall: 0.9748; F1: 0.9747
# 2026-05-06 15:45:19,782 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/baseline_cnn_mnist.yaml" "tuning/mnist/data_mnist.yaml" --seed "1" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:45:25,530 - INFO - ====================================================================================================
# 2026-05-06 15:45:25,531 - INFO - Running With Torch Seed: 1
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.021786, Val Loss: 0.08027, Val Acc: 0.975333, Val F1: 0.975003:
# 2026-05-06 15:45:34,709 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:45:34,709 - INFO - Accuracy: 0.9753; Precision: 0.9754; Recall: 0.9752; F1: 0.975
# 2026-05-06 15:45:34,709 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/baseline_cnn_mnist.yaml" "tuning/mnist/data_mnist.yaml" --seed "2" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:45:40,467 - INFO - ====================================================================================================
# 2026-05-06 15:45:40,467 - INFO - Running With Torch Seed: 2
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.05471, Val Loss: 0.171981, Val Acc: 0.947167, Val F1: 0.948527:
# 2026-05-06 15:45:49,619 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:45:49,620 - INFO - Accuracy: 0.9472; Precision: 0.9567; Recall: 0.9466; F1: 0.9485
# 2026-05-06 15:45:49,620 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/baseline_cnn_mnist.yaml" "tuning/mnist/data_mnist.yaml" --seed "3" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:45:55,505 - INFO - ====================================================================================================
# 2026-05-06 15:45:55,505 - INFO - Running With Torch Seed: 3
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.045587, Val Loss: 0.572121, Val Acc: 0.822583, Val F1: 0.838199
# 2026-05-06 15:46:04,120 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:46:04,120 - INFO - Accuracy: 0.8226; Precision: 0.9097; Recall: 0.8195; F1: 0.8382
# 2026-05-06 15:46:04,120 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/mnist/baseline_cnn_mnist.yaml" "tuning/mnist/data_mnist.yaml" --seed "4" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:46:09,966 - INFO - ====================================================================================================
# 2026-05-06 15:46:09,966 - INFO - Running With Torch Seed: 4
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.023272, Val Loss: 0.221393, Val Acc: 0.931167, Val F1: 0.930044
# 2026-05-06 15:46:18,768 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:46:18,768 - INFO - Accuracy: 0.9312; Precision: 0.939; Recall: 0.9296; F1: 0.93
# 2026-05-06 15:46:18,768 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
import numpy as np 

x = np.array([0.9766203717432237, 0.974162925228895, 0.9458060069454335, 0.8448199497137372, 0.9343742710278924])

print(x.mean())
print(x.std())
# Out:
# 0.9351567049318363
# 0.04799056171130741
