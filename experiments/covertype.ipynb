# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/dev/Deep-Arguing

# %% [markdown]
# ## Deep Arguing Model

# %%
! python src/deeparguing/cli/run.py --config "tuning/covertype/model_covertype.yaml" "tuning/covertype/hyperparameters_covertype.yaml" "tuning/covertype/data_covertype.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 15:20:15,896 - INFO - ====================================================================================================
# 2026-05-05 15:20:15,896 - INFO - Running With Torch Seed: 0
# Epoch 31, Loss: 0.923181, Val Loss: 0.94034, Val Acc: 0.743842, Val F1: 0.682388
# 2026-05-05 15:21:47,918 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-05 15:21:47,918 - INFO - Accuracy: 0.7438; Precision: 0.6412; Recall: 0.7426; F1: 0.6824
# 2026-05-05 15:21:47,918 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-05 15:21:47,921 - INFO - Confusion Matrix:
#           Pred 6  Pred 5  Pred 4  Pred 3  Pred 2  Pred 1  Pred 0
# Actual 6   23520    9006      21       0     330      93     789
# Actual 5    7482   35059     679      16    1088     920     112
# Actual 4       1     190    4634     216      35     696       0
# ...

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/covertype/baseline_nn_covertype.yaml" "tuning/covertype/data_covertype.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 12:46:49,067 - INFO - ====================================================================================================
# 2026-05-04 12:46:49,068 - INFO - Running With Torch Seed: 0
# Epoch 31, Loss: 0.541416, Val Loss: 0.571029, Val Acc: 0.733762, Val F1: 0.67174
# 2026-05-04 12:47:03,205 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 12:47:03,205 - INFO - Accuracy: 0.7338; Precision: 0.6225; Recall: 0.7698; F1: 0.6717
# 2026-05-04 12:47:03,205 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 12:47:03,208 - INFO - Confusion Matrix:
#           Pred 6  Pred 5  Pred 4  Pred 3  Pred 2  Pred 1  Pred 0
# Actual 6   23265    8811      13       0     556     101    1013
# Actual 5    7469   34125     526       6    2074    1036     120
# Actual 4       1     171    4311     288      65     936       0
# ...

# %% [markdown]
# ## DT Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/covertype/baseline_dt_covertype.yaml" "tuning/covertype/data_covertype.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 12:48:02,092 - INFO - ====================================================================================================
# 2026-05-04 12:48:02,092 - INFO - Running With Torch Seed: 0
# 2026-05-04 12:48:04,816 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 12:48:04,816 - INFO - Accuracy: 0.6977; Precision: 0.6866; Recall: 0.5335; F1: 0.5539
# 2026-05-04 12:48:04,816 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 12:48:04,820 - INFO - Confusion Matrix:
#           Pred 6  Pred 5  Pred 4  Pred 3  Pred 2  Pred 1  Pred 0
# Actual 6   17726   15697      13       0       0      16     307
# Actual 5    5313   39296     441       5      18     260      23
# Actual 4       3     582    4768     131      13     275       0
# Actual 3       0       0     166     288       0       9       0
# ...
