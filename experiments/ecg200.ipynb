# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/dev/Deep-Arguing

# %% [markdown]
# ## Deep Arguing Model

# %%
! python src/deeparguing/cli/run.py --config "tuning/ecg200/model_ecg200.yaml" "tuning/ecg200/hyperparameters_ecg200.yaml" "tuning/ecg200/data_ecg200.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 11:09:41,934 - INFO - ====================================================================================================
# 2026-05-06 11:09:41,934 - INFO - Running With Torch Seed: 0
# Traceback (most recent call last):
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 372, in <module>
#     average_f1 = run(args.project)()
#                  ^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 98, in objective
#     data_dict, instances = parse_model_config(
#                            ^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/parse_yaml.py", line 354, in parse_model_config
#     instances[key] = parse_entry(
#                      ^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/parse_yaml.py", line 242, in parse_entry
#     k: parse_entry(v, config, ref_stack, trial, device)
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/ecg200/baseline_lstm_ecg200.yaml" "tuning/ecg200/data_ecg200.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 11:09:44,974 - INFO - ====================================================================================================
# 2026-05-06 11:09:44,974 - INFO - Running With Torch Seed: 0
# Epoch 255, Loss: 0.588881, Val Loss: 0.558234, Val Acc: 0.85, Val F1: 0.811912:
# 2026-05-06 11:09:46,362 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 11:09:46,362 - INFO - Accuracy: 0.85; Precision: 0.8333; Recall: 0.7976; F1: 0.8119
# 2026-05-06 11:09:46,362 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-06 11:09:46,364 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1       4       2
# Actual 0       1      13
# 2026-05-06 11:09:46,367 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-06 11:09:46,367 - INFO - Accuracy: 0.68; Precision: 0.65; Recall: 0.6042; F1: 0.6032
# ...

# %% [markdown]
# ## DT Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/ecg200/baseline_dt_ecg200.yaml" "tuning/ecg200/data_ecg200.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 11:09:53,417 - INFO - ====================================================================================================
# 2026-05-06 11:09:53,417 - INFO - Running With Torch Seed: 0
# 2026-05-06 11:09:53,647 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 11:09:53,647 - INFO - Accuracy: 0.9; Precision: 0.875; Recall: 0.9286; F1: 0.8901
# 2026-05-06 11:09:53,647 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-06 11:09:53,648 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1       6       0
# Actual 0       2      12
# 2026-05-06 11:09:53,652 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-06 11:09:53,652 - INFO - Accuracy: 0.79; Precision: 0.7741; Recall: 0.763; F1: 0.7677
# ...

# %% [markdown]
# ## K-NN Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/ecg200/baseline_knn_ecg200.yaml" "tuning/ecg200/data_ecg200.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 11:09:56,558 - INFO - ====================================================================================================
# 2026-05-06 11:09:56,558 - INFO - Running With Torch Seed: 0
# 2026-05-06 11:09:56,824 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 11:09:56,824 - INFO - Accuracy: 0.85; Precision: 0.9118; Recall: 0.75; F1: 0.7849
# 2026-05-06 11:09:56,824 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-06 11:09:56,827 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1       3       3
# Actual 0       0      14
# 2026-05-06 11:09:56,832 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-06 11:09:56,832 - INFO - Accuracy: 0.9; Precision: 0.9095; Recall: 0.8733; F1: 0.8869
# ...
