# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/dev/Deep-Arguing

# %% [markdown]
# ## Deep Arguing Model

# %%
! python src/deeparguing/cli/run.py --config "tuning/higgs/model_higgs.yaml" "tuning/higgs/hyperparameters_higgs.yaml" "tuning/higgs/data_higgs.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 07:31:49,830 - INFO - ====================================================================================================
# 2026-05-06 07:31:49,830 - INFO - Running With Torch Seed: 0
# Epoch 31, Loss: 0.516896, Val Loss: 0.511847, Val Acc: 0.767341, Val F1: 0.76629
# 2026-05-06 07:57:50,248 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 07:57:50,248 - INFO - Accuracy: 0.7673; Precision: 0.7666; Recall: 0.7661; F1: 0.7663
# 2026-05-06 07:57:50,248 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-06 07:57:50,250 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1  616432  210481
# Actual 0  198998  734089
# 2026-05-06 07:57:52,411 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-06 07:57:52,411 - INFO - Accuracy: 0.7673; Precision: 0.7666; Recall: 0.7661; F1: 0.7663
# ...

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/higgs/baseline_nn_higgs.yaml" "tuning/higgs/data_higgs.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 00:23:58,642 - INFO - ====================================================================================================
# 2026-05-06 00:23:58,642 - INFO - Running With Torch Seed: 0
# Epoch 31, Loss: 0.43481, Val Loss: 0.453769, Val Acc: 0.781127, Val F1: 0.779871
# 2026-05-06 00:28:17,688 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 00:28:17,688 - INFO - Accuracy: 0.7811; Precision: 0.7807; Recall: 0.7794; F1: 0.7799
# 2026-05-06 00:28:17,688 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-06 00:28:17,690 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1  620903  206010
# Actual 0  179206  753881
# 2026-05-06 00:28:18,535 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-06 00:28:18,535 - INFO - Accuracy: 0.7804; Precision: 0.78; Recall: 0.7787; F1: 0.7792
# ...

# %% [markdown]
# ## DT Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/higgs/baseline_dt_higgs.yaml" "tuning/higgs/data_higgs.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 00:46:03,969 - INFO - ====================================================================================================
# 2026-05-06 00:46:03,969 - INFO - Running With Torch Seed: 0
# 2026-05-06 00:50:49,435 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 00:50:49,435 - INFO - Accuracy: 0.705; Precision: 0.7039; Recall: 0.7036; F1: 0.7037
# 2026-05-06 00:50:49,435 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-06 00:50:49,436 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1  563799  263114
# Actual 0  256152  676935
# 2026-05-06 00:52:59,316 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-06 00:52:59,316 - INFO - Accuracy: 0.7049; Precision: 0.7038; Recall: 0.7036; F1: 0.7037
# ...

# %% [markdown]
# ## K-NN Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/bank/baseline_knn_bank.yaml" "tuning/bank/data_bank.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 01:31:19,317 - INFO - ====================================================================================================
# 2026-05-06 01:31:19,317 - INFO - Running With Torch Seed: 0
# 2026-05-06 01:31:19,934 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 01:31:19,934 - INFO - Accuracy: 0.8894; Precision: 0.7324; Recall: 0.6571; F1: 0.6841
# 2026-05-06 01:31:19,934 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-06 01:31:19,936 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1    6133     249
# Actual 0     551     301
# 2026-05-06 01:31:20,078 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-06 01:31:20,078 - INFO - Accuracy: 0.8912; Precision: 0.7458; Recall: 0.6752; F1: 0.7017
# ...
