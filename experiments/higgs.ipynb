# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/dev/Deep-Arguing

# %% [markdown]
# ## Deep Arguing Model

# %%
! python src/deeparguing/cli/run.py --config "tuning/higgs/model_higgs.yaml" "tuning/higgs/hyperparameters_higgs.yaml" "tuning/higgs/data_higgs.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 13:40:06,874 - INFO - ====================================================================================================
# 2026-05-04 13:40:06,874 - INFO - Running With Torch Seed: 0
# Epoch 0, Loss: 0.522491, Val Loss: 0.532315, Val Acc: 0.752185, Val F1: 0.750313
# Traceback (most recent call last):
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 372, in <module>
#     average_f1 = run(args.project)()
#                  ^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 173, in objective
#     max_val_acc, max_val_f1 = trainer.train(
#                               ^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/train/simple_trainer.py", line 111, in train
#     loss = self._train_step(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/train/simple_trainer.py", line 55, in _train_step
#     predictions = model(X_new_cases).squeeze()
#                   ^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/gradual_aacbr.py", line 538, in forward
#     base_scores = self.__new_case_influence(self.X_train, base_scores, new_cases)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/gradual_aacbr.py", line 571, in __new_case_influence
#     new_cases_attacks_adjacency = self.irrelevance_edge_weights(
#                                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/irrelevance_edge_weights/regular_irrelevance.py", line 21, in forward
#     return 1 - self.compute_partial_order(new_cases, X_train)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/casebase_edge_weights/learned_partial_order.py", line 48, in forward
#     attacker_emb = self._extract_features(attacker)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/casebase_edge_weights/learned_partial_order.py", line 29, in _extract_features
#     x = feature_extractor(x)
#         ^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/feature_extractor/mlp_extractor.py", line 50, in forward
#     case = layer(case)
#            ^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/gradual-aacbr/lib/python3.12/site-packages/torch/nn/modules/linear.py", line 125, in forward
#     return F.linear(input, self.weight, self.bias)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# ^C

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/higgs/baseline_nn_higgs.yaml" "tuning/higgs/data_higgs.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# Traceback (most recent call last):
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 372, in <module>
#     average_f1 = run(args.project)()
#                  ^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 58, in objective
#     model_config = read_config_files(args.config)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/parse_yaml.py", line 58, in read_config_files
#     with open(config_file_path, "r") as file:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'tuning/higgs/baseline_nn_higgs.yaml'

# %% [markdown]
# ## DT Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/higgs/baseline_dt_higgs.yaml" "tuning/higgs/data_higgs.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 15:39:39,048 - INFO - ====================================================================================================
# 2026-05-05 15:39:39,048 - INFO - Running With Torch Seed: 0
# ^C
