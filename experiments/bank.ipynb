# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/dev/Deep-Arguing

# %% [markdown]
# ## Deep Arguing Model

# %%
! python src/deeparguing/cli/run.py --config "tuning/bank/model_bank.yaml" "tuning/bank/hyperparameters_bank.yaml" "tuning/bank/data_bank.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 17:40:37,743 - INFO - ====================================================================================================
# 2026-05-04 17:40:37,743 - INFO - Running With Torch Seed: 0
# Epoch 9, Loss: 0.287819, Val Loss: 0.316027, Val Acc: 0.88872, Val F1: 0.770591:
# 2026-05-04 17:41:10,695 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 17:41:10,695 - INFO - Accuracy: 0.8887; Precision: 0.7406; Recall: 0.8184; F1: 0.7706
# 2026-05-04 17:41:10,695 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 17:41:10,697 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1    5810     572
# Actual 0     233     619
# 2026-05-04 17:41:10,877 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-04 17:41:10,877 - INFO - Accuracy: 0.8885; Precision: 0.744; Recall: 0.8188; F1: 0.7732
# ...

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/bank/baseline_nn_bank.yaml" "tuning/bank/data_bank.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 17:43:26,335 - INFO - ====================================================================================================
# 2026-05-04 17:43:26,335 - INFO - Running With Torch Seed: 0
# Epoch 9, Loss: 0.182732, Val Loss: 0.307205, Val Acc: 0.880011, Val F1: 0.767697
# 2026-05-04 17:43:28,463 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 17:43:28,463 - INFO - Accuracy: 0.88; Precision: 0.7314; Recall: 0.8384; F1: 0.7677
# 2026-05-04 17:43:28,463 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 17:43:28,465 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1    5698     684
# Actual 0     184     668
# 2026-05-04 17:43:28,475 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-04 17:43:28,475 - INFO - Accuracy: 0.879; Precision: 0.7329; Recall: 0.8343; F1: 0.7679
# ...

# %% [markdown]
# ## DT Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/bank/baseline_dt_bank.yaml" "tuning/bank/data_bank.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 17:43:38,342 - INFO - ====================================================================================================
# 2026-05-04 17:43:38,342 - INFO - Running With Torch Seed: 0
# 2026-05-04 17:43:38,899 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 17:43:38,900 - INFO - Accuracy: 0.9019; Precision: 0.7713; Recall: 0.7064; F1: 0.7325
# 2026-05-04 17:43:38,900 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 17:43:38,902 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1    6140     242
# Actual 0     468     384
# 2026-05-04 17:43:38,990 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-04 17:43:38,991 - INFO - Accuracy: 0.8984; Precision: 0.7689; Recall: 0.6947; F1: 0.7232
# ...
