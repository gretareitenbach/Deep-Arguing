# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/dev/Deep-Arguing

# %% [markdown]
# ## Deep Arguing Model

# %%
! python src/deeparguing/cli/run.py --config "tuning/glioma/model_glioma.yaml" "tuning/glioma/hyperparameters_glioma.yaml" "tuning/glioma/data_glioma.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 13:55:28,468 - INFO - ====================================================================================================
# 2026-05-04 13:55:28,468 - INFO - Running With Torch Seed: 0
# Epoch 31, Loss: 0.103857, Val Loss: 0.578396, Val Acc: 0.822222, Val F1: 0.81092
# 2026-05-04 13:55:32,792 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 13:55:32,792 - INFO - Accuracy: 0.8222; Precision: 0.8062; Recall: 0.8586; F1: 0.8109
# 2026-05-04 13:55:32,792 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 13:55:32,794 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1      72      22
# Actual 0       2      39
# 2026-05-04 13:55:32,801 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-04 13:55:32,801 - INFO - Accuracy: 0.8214; Precision: 0.8218; Recall: 0.8229; F1: 0.8213
# ...

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/glioma/baseline_nn_glioma.yaml" "tuning/glioma/data_glioma.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 13:55:50,868 - INFO - ====================================================================================================
# 2026-05-04 13:55:50,868 - INFO - Running With Torch Seed: 0
# Epoch 31, Loss: 0.084227, Val Loss: 0.805407, Val Acc: 0.8, Val F1: 0.78961: 100
# 2026-05-04 13:55:51,704 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 13:55:51,704 - INFO - Accuracy: 0.8; Precision: 0.7906; Recall: 0.8426; F1: 0.7896
# 2026-05-04 13:55:51,704 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 13:55:51,706 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1      69      25
# Actual 0       2      39
# 2026-05-04 13:55:51,709 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-04 13:55:51,709 - INFO - Accuracy: 0.7857; Precision: 0.785; Recall: 0.785; F1: 0.785
# ...

# %% [markdown]
# ## DT Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/glioma/baseline_dt_glioma.yaml" "tuning/glioma/data_glioma.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-04 13:56:31,811 - INFO - ====================================================================================================
# 2026-05-04 13:56:31,811 - INFO - Running With Torch Seed: 0
# 2026-05-04 13:56:32,002 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-04 13:56:32,002 - INFO - Accuracy: 0.8222; Precision: 0.8062; Recall: 0.8586; F1: 0.8109
# 2026-05-04 13:56:32,002 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-04 13:56:32,004 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1      72      22
# Actual 0       2      39
# 2026-05-04 13:56:32,008 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-04 13:56:32,008 - INFO - Accuracy: 0.8214; Precision: 0.8243; Recall: 0.8243; F1: 0.8214
# ...

# %% [markdown]
# ## K-NN Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/glioma/baseline_knn_glioma.yaml" "tuning/glioma/data_glioma.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 19:10:03,866 - INFO - ====================================================================================================
# 2026-05-05 19:10:03,867 - INFO - Running With Torch Seed: 0
# 2026-05-05 19:10:04,115 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-05 19:10:04,115 - INFO - Accuracy: 0.7852; Precision: 0.7562; Recall: 0.7907; F1: 0.7645
# 2026-05-05 19:10:04,115 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-05 19:10:04,117 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1      73      21
# Actual 0       8      33
# 2026-05-05 19:10:04,123 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-05 19:10:04,123 - INFO - Accuracy: 0.8512; Precision: 0.8521; Recall: 0.8532; F1: 0.8511
# ...

# %% [markdown]
# ## Gradual AA-CBR (NeSy Paper)

# %%
! python src/deeparguing/cli/run.py --config "tuning/glioma/nalcbr_glioma.yaml" "tuning/glioma/data_glioma.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 15:51:51,802 - INFO - ====================================================================================================
# 2026-05-06 15:51:51,802 - INFO - Running With Torch Seed: 0
# Epoch 31, Loss: 0.693149, Val Loss: 0.693149, Val Acc: 0.696296, Val F1: 0.41048
# 2026-05-06 15:52:33,750 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 15:52:33,750 - INFO - Accuracy: 0.6963; Precision: 0.3481; Recall: 0.5; F1: 0.4105
# 2026-05-06 15:52:33,750 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-06 15:52:33,751 - INFO - Confusion Matrix:
#           Pred 1  Pred 0
# Actual 1      94       0
# Actual 0      41       0
# 2026-05-06 15:52:33,779 - INFO - ------------------------------ RESULTS ON THE TEST SET ------------------------------
# 2026-05-06 15:52:33,779 - INFO - Accuracy: 0.5298; Precision: 0.2649; Recall: 0.5; F1: 0.3463
# ...
