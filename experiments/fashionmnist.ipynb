# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/Documents/dev/gradual-aacbr

# %% [markdown]
# ## Deep Arguing Model

# %% [markdown]
# Note there is a bug with the weights of the CNN not initialsing correctly when running each seed sequentially in one go, so instead each was run separately and the results averaged.

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/data_fashionmnist.yaml" "tuning/fashionmnist/hyperparameters_fashionmnist.yaml" "tuning/fashionmnist/model_fashionmnist.yaml" --seed "0" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 17:39:22,318 - INFO - ====================================================================================================
# 2026-05-06 17:39:22,318 - INFO - Running With Torch Seed: 0
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.768035, Val Loss: 0.841635, Val Acc: 0.846833, Val F1: 0.847333
# 2026-05-06 17:41:15,204 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 17:41:15,204 - INFO - Accuracy: 0.8468; Precision: 0.8529; Recall: 0.8493; F1: 0.8473
# 2026-05-06 17:41:15,204 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/data_fashionmnist.yaml" "tuning/fashionmnist/hyperparameters_fashionmnist.yaml" "tuning/fashionmnist/model_fashionmnist.yaml" --seed "1" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 17:41:23,158 - INFO - ====================================================================================================
# 2026-05-06 17:41:23,158 - INFO - Running With Torch Seed: 1
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.727565, Val Loss: 0.834347, Val Acc: 0.844667, Val F1: 0.845258
# 2026-05-06 17:43:16,123 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 17:43:16,124 - INFO - Accuracy: 0.8447; Precision: 0.8478; Recall: 0.8473; F1: 0.8453
# 2026-05-06 17:43:16,124 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/data_fashionmnist.yaml" "tuning/fashionmnist/hyperparameters_fashionmnist.yaml" "tuning/fashionmnist/model_fashionmnist.yaml" --seed "2" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 17:43:23,791 - INFO - ====================================================================================================
# 2026-05-06 17:43:23,791 - INFO - Running With Torch Seed: 2
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.683431, Val Loss: 0.809451, Val Acc: 0.849333, Val F1: 0.84871:
# 2026-05-06 17:45:15,335 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 17:45:15,335 - INFO - Accuracy: 0.8493; Precision: 0.8555; Recall: 0.8513; F1: 0.8487
# 2026-05-06 17:45:15,335 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/data_fashionmnist.yaml" "tuning/fashionmnist/hyperparameters_fashionmnist.yaml" "tuning/fashionmnist/model_fashionmnist.yaml" --seed "3" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 17:45:22,913 - INFO - ====================================================================================================
# 2026-05-06 17:45:22,913 - INFO - Running With Torch Seed: 3
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.653328, Val Loss: 0.82035, Val Acc: 0.845667, Val F1: 0.845585:
# 2026-05-06 17:47:14,255 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 17:47:14,255 - INFO - Accuracy: 0.8457; Precision: 0.8478; Recall: 0.848; F1: 0.8456
# 2026-05-06 17:47:14,255 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/data_fashionmnist.yaml" "tuning/fashionmnist/hyperparameters_fashionmnist.yaml" "tuning/fashionmnist/model_fashionmnist.yaml" --seed "4" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 17:47:22,103 - INFO - ====================================================================================================
# 2026-05-06 17:47:22,103 - INFO - Running With Torch Seed: 4
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.797574, Val Loss: 0.763939, Val Acc: 0.86675, Val F1: 0.868873:
# 2026-05-06 17:49:15,053 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 17:49:15,053 - INFO - Accuracy: 0.8668; Precision: 0.871; Recall: 0.8687; F1: 0.8689
# 2026-05-06 17:49:15,053 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
import numpy as np 

x = np.array([0.8454681732394386, 0.8378977220037818, 0.8499608042233676, 0.840828526845379, 0.8673064171456437])

print(x.mean())
print(x.std())
# Out:
# 0.8482923286915222
# 0.010354239813239467

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/baseline_cnn_fashionmnist.yaml" "tuning/fashionmnist/data_fashionmnist.yaml" --seed "0" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 18:18:50,817 - INFO - ====================================================================================================
# 2026-05-06 18:18:50,817 - INFO - Running With Torch Seed: 0
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.266909, Val Loss: 0.380459, Val Acc: 0.856833, Val F1: 0.861426
# 2026-05-06 18:18:59,908 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 18:18:59,908 - INFO - Accuracy: 0.8568; Precision: 0.8872; Recall: 0.8574; F1: 0.8614
# 2026-05-06 18:18:59,908 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/baseline_cnn_fashionmnist.yaml" "tuning/fashionmnist/data_fashionmnist.yaml" --seed "1" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 18:19:05,809 - INFO - ====================================================================================================
# 2026-05-06 18:19:05,809 - INFO - Running With Torch Seed: 1
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.240075, Val Loss: 0.852504, Val Acc: 0.73925, Val F1: 0.732455:
# 2026-05-06 18:19:14,823 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 18:19:14,823 - INFO - Accuracy: 0.7392; Precision: 0.8283; Recall: 0.7405; F1: 0.7325
# 2026-05-06 18:19:14,823 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/baseline_cnn_fashionmnist.yaml" "tuning/fashionmnist/data_fashionmnist.yaml" --seed "2" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 18:19:20,710 - INFO - ====================================================================================================
# 2026-05-06 18:19:20,710 - INFO - Running With Torch Seed: 2
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.245703, Val Loss: 0.432715, Val Acc: 0.849417, Val F1: 0.850469
# 2026-05-06 18:19:30,181 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 18:19:30,181 - INFO - Accuracy: 0.8494; Precision: 0.8783; Recall: 0.851; F1: 0.8505
# 2026-05-06 18:19:30,181 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/baseline_cnn_fashionmnist.yaml" "tuning/fashionmnist/data_fashionmnist.yaml" --seed "3" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 18:19:36,290 - INFO - ====================================================================================================
# 2026-05-06 18:19:36,290 - INFO - Running With Torch Seed: 3
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.190701, Val Loss: 0.643298, Val Acc: 0.7845, Val F1: 0.774576:
# 2026-05-06 18:19:45,729 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 18:19:45,729 - INFO - Accuracy: 0.7845; Precision: 0.8322; Recall: 0.789; F1: 0.7746
# 2026-05-06 18:19:45,729 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
! python src/deeparguing/cli/run.py --config "tuning/fashionmnist/baseline_cnn_fashionmnist.yaml" "tuning/fashionmnist/data_fashionmnist.yaml" --seed "4" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 18:19:51,684 - INFO - ====================================================================================================
# 2026-05-06 18:19:51,685 - INFO - Running With Torch Seed: 4
# /home/adam/Documents/dev/gradual-aacbr/src/deeparguing/helper.py:202: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   y = torch.tensor(dataset.targets, dtype=torch.long)
# Epoch 9, Loss: 0.197478, Val Loss: 0.369328, Val Acc: 0.865333, Val F1: 0.865626
# 2026-05-06 18:20:01,243 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-06 18:20:01,243 - INFO - Accuracy: 0.8653; Precision: 0.8856; Recall: 0.868; F1: 0.8656
# 2026-05-06 18:20:01,243 - INFO - -------------------------------------------------------------------------------------------
# ...

# %%
import numpy as np 

x = np.array([0.8582696755823582, 0.7304099407053417, 0.8471087694601038, 0.7712912574950865, 0.8636446260404576])


print(x.mean())
print(x.std())
# Out:
# 0.8141448538566696
# 0.05353842259921926
