# %%
import os
import sys
import pathlib

# Set to the root directory - 
# only allow this to run once in the jupyter session
if 'changed_root' not in locals():
    os.chdir(os.path.dirname(os.getcwd()))
    changed_root = True
print(os.getcwd())
# Out:
# /home/adam/dev/Deep-Arguing

# %% [markdown]
# ## Deep Arguing Model

# %%
! python src/deeparguing/cli/run.py --config "tuning/chess/model_chess.yaml" "tuning/chess/hyperparameters_chess.yaml" "tuning/chess/data_chess.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 13:57:16,166 - INFO - ====================================================================================================
# 2026-05-05 13:57:16,166 - INFO - Running With Torch Seed: 0
# Epoch 1023, Loss: 0.520629, Val Loss: 1.056873, Val Acc: 0.777456, Val F1: 0.764
# 2026-05-05 14:07:50,036 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-05 14:07:50,036 - INFO - Accuracy: 0.7775; Precision: 0.7569; Recall: 0.7972; F1: 0.7649
# 2026-05-05 14:07:50,036 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-05 14:07:50,044 - INFO - Confusion Matrix:
#            Pred 17  Pred 16  Pred 15  Pred 14  ...  Pred 3  Pred 2  Pred 1  Pred 0
# Actual 17      387        2        3        0  ...       1       0       0       0
# Actual 16        2      180        1        0  ...       0       1       0       0
# ...

# %% [markdown]
# ## Neural Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/chess/baseline_nn_chess.yaml" "tuning/chess/data_chess.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 14:50:10,917 - INFO - ====================================================================================================
# 2026-05-05 14:50:10,917 - INFO - Running With Torch Seed: 0
# Epoch 1023, Loss: 0.091602, Val Loss: 0.92854, Val Acc: 0.813321, Val F1: 0.7985
# 2026-05-05 14:50:48,294 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-05 14:50:48,294 - INFO - Accuracy: 0.8133; Precision: 0.8182; Recall: 0.7962; F1: 0.7985
# 2026-05-05 14:50:48,294 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-05 14:50:48,300 - INFO - Confusion Matrix:
#            Pred 17  Pred 16  Pred 15  Pred 14  ...  Pred 3  Pred 2  Pred 1  Pred 0
# Actual 17      401        0        0        2  ...       1       0       0       0
# Actual 16        6      200        3        0  ...       0       1       0       0
# ...

# %% [markdown]
# ## DT Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/chess/baseline_dt_chess.yaml" "tuning/chess/data_chess.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 14:53:28,561 - INFO - ====================================================================================================
# 2026-05-05 14:53:28,561 - INFO - Running With Torch Seed: 0
# 2026-05-05 14:53:28,838 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-05 14:53:28,838 - INFO - Accuracy: 0.4961; Precision: 0.6359; Recall: 0.5419; F1: 0.5749
# 2026-05-05 14:53:28,838 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-05 14:53:28,844 - INFO - Confusion Matrix:
#            Pred 17  Pred 16  Pred 15  Pred 14  ...  Pred 3  Pred 2  Pred 1  Pred 0
# Actual 17       46       14       36       25  ...       2      70       0       0
# Actual 16       27      125        6        0  ...       0       8       0       0
# Actual 15       14        1      215        8  ...       0      84       0       0
# ...

# %% [markdown]
# ## K-NN Baseline

# %%
! python src/deeparguing/cli/run.py --config "tuning/chess/baseline_knn_chess.yaml" "tuning/chess/data_chess.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-05 19:09:19,974 - INFO - ====================================================================================================
# 2026-05-05 19:09:19,974 - INFO - Running With Torch Seed: 0
# 2026-05-05 19:09:20,336 - INFO - ------------------------------ RESULTS ON THE VALIDATION SET ------------------------------
# 2026-05-05 19:09:20,336 - INFO - Accuracy: 0.4226; Precision: 0.4284; Recall: 0.3492; F1: 0.3618
# 2026-05-05 19:09:20,336 - INFO - -------------------------------------------------------------------------------------------
# 2026-05-05 19:09:20,347 - INFO - Confusion Matrix:
#            Pred 17  Pred 16  Pred 15  Pred 14  ...  Pred 3  Pred 2  Pred 1  Pred 0
# Actual 17      226       13       27       25  ...       3      22       0       0
# Actual 16       40      136       11        3  ...       0       3       0       0
# Actual 15       67       24      226        9  ...       0      41       0       0
# ...

# %% [markdown]
# ## Gradual AA-CBR (NeSy Paper)

# %%
! python src/deeparguing/cli/run.py --config "tuning/chess/nalcbr_chess.yaml" "tuning/chess/data_chess.yaml" --seed "(0, 5)" --log "info" --run_train -lv --run_test
# Out:
# 2026-05-06 16:08:07,324 - INFO - ====================================================================================================
# 2026-05-06 16:08:07,324 - INFO - Running With Torch Seed: 0
#   0%|                                                  | 0/1024 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 372, in <module>
#     average_f1 = run(args.project)()
#                  ^^^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/cli/run.py", line 173, in objective
#     max_val_acc, max_val_f1 = trainer.train(
#                               ^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/train/simple_trainer.py", line 111, in train
#     loss = self._train_step(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/adam/dev/Deep-Arguing/src/deeparguing/train/simple_trainer.py", line 53, in _train_step
#     model.fit(X_casebase, y_casebase, X_default, y_default)
# ...
